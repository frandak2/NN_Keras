# %% [markdown]
# # Regression

# %% [markdown]
# ### Importando librerías

# %%
import pandas as pd
import numpy as np
from keras.datasets import boston_housing 
from keras import models, layers, optimizers

# %% [markdown]
# ### Descargando datos

# %%
(train_data , train_targets) ,(test_data,test_targets) = boston_housing.load_data()

# %%
train_data[1]
# Out:
# array([2.1770e-02, 8.2500e+01, 2.0300e+00, 0.0000e+00, 4.1500e-01,
#        7.6100e+00, 1.5700e+01, 6.2700e+00, 2.0000e+00, 3.4800e+02,
#        1.4700e+01, 3.9538e+02, 3.1100e+00])

# %%
train_targets[1]
# Out:
# 42.3

# %% [markdown]
# ## Normalización

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.fit_transform(test_data)

# %% [markdown]
# ### Definiendo nuestra red

# %%
def build_model_regression(input_data):
    model = models.Sequential()
    model.add(layers.Dense(64,activation='relu',input_shape=(input_data,)))
    model.add(layers.Dense(64,activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse',metrics=['mae'])
    return model

# %% [markdown]
# ## K - fold validation

# %%
k = 4
num_val_samples = len(trainSc) // 4
num_epoch = 500
all_history = []

# %%
0*num_val_samples
# Out:
# 0

# %%
(0+1) * num_val_samples
# Out:
# 101

# %%
for i in range(k):
    print("Fold " , i)
    val_data = train_data[i*num_val_samples: (i+1) * num_val_samples]
    val_targets = train_targets[i*num_val_samples: (i+1) * num_val_samples]
    
    partial_train_data = np.concatenate(
    [train_data[:i * num_val_samples],
     train_data[(i+1) * num_val_samples:]],
     axis= 0   
    )
    
    partial_train_targets = np.concatenate(
    [train_targets[:i * num_val_samples],
     train_targets[(i+1) * num_val_samples:]],
     axis= 0   
    )    
    model = build_model_regression(13)
    history = model.fit(partial_train_data, partial_train_targets, epochs=num_epoch, batch_size =16, 
                        validation_data = (val_data, val_targets),
                        verbose=0)
    all_history.append(history.history['val_mae'])
# Out:
# Fold  0
# Fold  1
# Fold  2
# Fold  3

# %% [markdown]
# ### Media de todos los MAE

# %%
len(all_history[0])
# Out:
# 500

# %%
all_mae_avg = pd.DataFrame(all_history).mean(axis=0)

# %% [markdown]
# ### Visualizando resultados

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,10))
plt.plot(range(1,len(all_mae_avg[15:])+1), all_mae_avg[15:])
plt.show()

# %% [markdown]
# ### Evaluando el modelo

# %%
model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 11.3168 - mae: 2.5434
# [11.316780090332031, 2.5433712005615234]

# %% [markdown]
# # Tuning

# %%
num_epoch = 120
all_history = []
for i in range(k):
    print("Fold " , i)
    val_data = train_data[i*num_val_samples: (i+1) * num_val_samples]
    val_targets = train_targets[i*num_val_samples: (i+1) * num_val_samples]
    
    partial_train_data = np.concatenate(
    [train_data[:i * num_val_samples],
     train_data[(i+1) * num_val_samples:]],
     axis= 0   
    )
    
    partial_train_targets = np.concatenate(
    [train_targets[:i * num_val_samples],
     train_targets[(i+1) * num_val_samples:]],
     axis= 0   
    )    
    model = build_model_regression(13)
    history = model.fit(partial_train_data, partial_train_targets, epochs=num_epoch, batch_size =16, 
                        validation_data = (val_data, val_targets),
                        verbose=0)
    all_history.append(history.history['val_mae'])
# Out:
# Fold  0
# Fold  1
# Fold  2
# Fold  3

# %%
all_mae_avg = pd.DataFrame(all_history).mean(axis=0)
fig = plt.figure(figsize=(10,10))
plt.plot(range(1,len(all_mae_avg[15:])+1), all_mae_avg[15:])
plt.show()

# %%
num_epoch = 98
all_history = []
for i in range(k):
    print("Fold " , i)
    val_data = train_data[i*num_val_samples: (i+1) * num_val_samples]
    val_targets = train_targets[i*num_val_samples: (i+1) * num_val_samples]
    
    partial_train_data = np.concatenate(
    [train_data[:i * num_val_samples],
     train_data[(i+1) * num_val_samples:]],
     axis= 0   
    )
    
    partial_train_targets = np.concatenate(
    [train_targets[:i * num_val_samples],
     train_targets[(i+1) * num_val_samples:]],
     axis= 0   
    )    
    model = build_model_regression(13)
    history = model.fit(partial_train_data, partial_train_targets, epochs=num_epoch, batch_size =16, 
                        validation_data = (val_data, val_targets),
                        verbose=0)
    all_history.append(history.history['val_mae'])
# Out:
# Fold  0
# Fold  1
# Fold  2
# Fold  3

# %%
all_mae_avg = pd.DataFrame(all_history).mean(axis=0)
fig = plt.figure(figsize=(10,10))
plt.plot(range(1,len(all_mae_avg[15:])+1), all_mae_avg[15:])
plt.show()

# %%
model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 19.1032 - mae: 2.7904
# [19.103178024291992, 2.7903900146484375]
